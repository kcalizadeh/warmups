# %%
import pandas as pd
import numpy as np

# %%
# plot a correlation heatmap for the following dataframe
# use seaborn heatmap to do this

# %%
df = pd.read_csv("./data/regression_example.csv")
df.head()
# Out:
#    feature_1  feature_2  feature_3  feature_4  feature_5      target
# 0  -0.088892  -1.604297  -0.535592  -0.154560  -1.717940  -24.664450
# 1   0.655554   0.596035  -0.022727  -0.314452  -0.104125   -1.326799
# 2   1.384427   0.288676  -1.703491   0.732984   0.651311  -15.779122
# 3   0.845429   2.329748  -0.146867   0.307365   0.302064   16.784020
# 4   0.181319  -0.000635  -1.071908  -2.549141  -0.384905 -115.073177

# %%
import seaborn as sns
sns.heatmap(df.corr(), center=0, cmap=sns.color_palette('Blues'))
